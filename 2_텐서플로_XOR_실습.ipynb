# %% [markdown]
# <a href="https://colab.research.google.com/github/22yuu/Colab/blob/main/2_%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C_XOR_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2021/07/12
이름 : 이진유
내용 : 텐서플로 기초 실습하기
"""

import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import mse

tf.__version__
# Out:
# '2.5.0'

# %%
# 데이터 준비
data = np.array([[0, 1], [0,1], [1,0], [1,1]])
label = np.array([[0], [1], [1], [0]])

# %%
# 학습모델 설계
model = Sequential()
model.add(Dense(units=100, input_dim=2, activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
# 모델설정
model.compile(optimizer='Adam', loss = mse, metrics=('acc'))

# %%
# 학습하기
model.fit(data, label, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 353ms/step - loss: 0.2906 - acc: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2856 - acc: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2808 - acc: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2763 - acc: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2720 - acc: 0.5000
# Epoch 6/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2679 - acc: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2642 - acc: 0.5000
# Epoch 8/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2608 - acc: 0.5000
# Epoch 9/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2578 - acc: 0.5000
# Epoch 10/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2551 - acc: 0.5000
# Epoch 11/1000
# ...

# %%
# 검증하기
result = model.predict([[0,1],[1,1],[1,0]])
result
# Out:
# array([[0.4982688 ],
#        [0.07055104],
#        [0.9348789 ]], dtype=float32)
